# %%
import IPython
IPython.display.Image(r"C:\Users\HP\Downloads\OIP.jpeg")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# ML
from sklearn import *
print('done')
# Out:
# done

# %%
data = {'Study_hrs':range(1,11),
       'Marks Obtained':[25,33,46,50,55,67,78,85,95,100]}

df = pd.DataFrame(data)
df
# Out:
#    Study_hrs  Marks Obtained
# 0          1              25
# 1          2              33
# 2          3              46
# 3          4              50
# 4          5              55
# 5          6              67
# 6          7              78
# 7          8              85
# 8          9              95
# 9         10             100

# %%
# ML model build?: x, y: +ve, -ve
# Scatter Plot
plt.title('Study vs Marks')
plt.scatter(df['Study_hrs'],df['Marks Obtained'],marker = 'o', color = 'b')
plt.xlabel('Study Hrs')
plt.ylabel('Marks')
plt.show()

# %%
# Training : Zero error
# Future: Predict:

# %%
# # Y = mx + c
# # M : Slope
# # C : Intercept

# Y = Marks
# x = Study_hrs

# %%
# x(1), y(1): simple Linear Regression
# x(multiple): y(1): Multiple Linear Regression

df
# Out:
#    Study_hrs  Marks Obtained
# 0          1              25
# 1          2              33
# 2          3              46
# 3          4              50
# 4          5              55
# 5          6              67
# 6          7              78
# 7          8              85
# 8          9              95
# 9         10             100

# %%
# Import Module
from sklearn.linear_model import LinearRegression

# Object Model Creation
model = LinearRegression()


# X, y
X = df[['Study_hrs']]
y = df['Marks Obtained']


# Training/Learning
model.fit(X,y)
# Out:
# LinearRegression()

# %%
m = model.coef_
c = model.intercept_
print(m,c)
# Out:
# [8.48484848] 16.73333333333334

# %%
std_hrs = [[5.5]]

marks = m * std_hrs + c
# y = mx + c
# "y = β₀ + β₁x"
# y = wx +  c

print('Predicted Marks: ',marks[0][0])
# Out:
# Predicted Marks:  63.4

# %%
import warnings
warnings.filterwarnings('ignore')
study_hrs = input('Enter study hours: ')

std_hr = [[float(study_hrs)]]

ans = model.predict(std_hr)
marks = round(ans[0],2)

if marks > 100:
  marks = 100

elif marks<0:
  marks = 0

else:
  marks = marks

print(f'Your Predicted marks is: {marks}')
# Out:
# Enter study hours:  5
# Your Predicted marks is: 59.16

# %%
study_hrs = input('enter study hours')
sthr = [[float(study_hrs)]]

ans = model.predict(sthr)
print(f'your predicted marks is: {ans[0]}')
# Out:
# enter study hours 5.9
# your predicted marks is: 66.79393939393938
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Multiple(Features: X more than 1)

import kagglehub

# Download latest version
path = kagglehub.dataset_download("ashydv/advertising-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/ashydv/advertising-dataset?dataset_version_number=1...
# 100%|██████████| 1.83k/1.83k [00:00<00:00, 704kB/s]
# Extracting files...
# Path to dataset files: C:\Users\HP\.cache\kagglehub\datasets\ashydv\advertising-dataset\versions\1

# %%
import os

os.listdir(path)
# Out:
# ['advertising.csv']

# %%
file_path = path + '/' + os.listdir(path)[0]
print(file_path)
# Out:
# C:\Users\HP\.cache\kagglehub\datasets\ashydv\advertising-dataset\versions\1/advertising.csv

# %%
df_multi = pd.read_csv(file_path)
df_multi.sample(5)
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 133  219.8   33.5       45.1   19.6
# 47   239.9   41.5       18.5   23.2
# 92   217.7   33.5       59.0   19.4
# 64   131.1   42.8       28.9   16.0

# %%
# Description:
# The advertising dataset captures the sales revenue generated
# with respect to advertisement costs across multiple channels like radio, tv, and newspapers.
# It is required to understand the impact of ad budgets on the overall sales.

# %%
# y = m*x + c

# X = 3 features

# y = m1*x1 + m2*x2 + m3*x3 + c

# y =  β₀+ β1*x1 + β2*x2 + β3*x3

# x1 = TV_budget
# x2 = radio
# x3 = newspaper
