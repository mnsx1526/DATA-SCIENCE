# %%
# fillna
# replace
# drop
# Corr
# outliers detection
# pivot table

# Matplotlib Charts
'''Bar, Pie, Line, Box, violin'''
# Seaborn Charts
'''Bar, Line, Heatmap, Box, Violin, CatPlot, Regplolt, lmplot'''

#Feature Engineering
print('Topics for Today')
# Out:
# Topics for Today

# %%
''' STEPS TO PERFORM EDA
1. IMPORT THE DATA
2. STORE THE PATH FOR DYNAMIC APPROACH
3. IMPORT NECESSARY LIBRARIES
4. CHECK THE SHAPE
5. INFO OF THE DATA (CHECK FOR NULL VALUES)
6. VIEW ALL THE COLUMNS
7. COUNT THE NULL VALUES
8. MAKE THE HEAT MAP OF THE FILE
9. CALCULATE PERCENTAGE OF NULL VALUES
10. ANALYSE THE NAN COLUMNS
11. DECIDE BETWEEN FILLING OR DROPPING THE NAN COLUMN
'''
# Out:
# ' STEPS TO PERFORM EDA\n1. IMPORT THE DATA\n2. STORE THE PATH FOR DYNAMIC APPROACH\n3. IMPORT NECESSARY LIBRARIES\n4. CHECK THE SHAPE\n5. INFO OF THE DATA (CHECK FOR NULL VALUES)\n6. VIEW ALL THE COLUMNS\n7. COUNT THE NULL VALUES\n8. MAKE THE HEAT MAP OF THE FILE\n9. CALCULATE PERCENTAGE OF NULL VALUES\n10. ANALYSE THE NAN COLUMNS\n11. DECIDE BETWEEN FILLING OR DROPPING THE NAN COLUMN\n'

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("patrickb1912/ipl-complete-dataset-20082020")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\HP\.cache\kagglehub\datasets\patrickb1912\ipl-complete-dataset-20082020\versions\3

# %%
import os
file1 , file2 = os.listdir(path)
#print('done')

# %%
file1_path = path + '/' + file1
file2_path = path + '/' + file2

# %%
print(file1_path)
print(file2_path)
# Out:
# C:\Users\HP\.cache\kagglehub\datasets\patrickb1912\ipl-complete-dataset-20082020\versions\3/deliveries.csv
# C:\Users\HP\.cache\kagglehub\datasets\patrickb1912\ipl-complete-dataset-20082020\versions\3/matches.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
print('done')
# Out:
# done

# %%
df_deliveries = pd.read_csv(file1_path)
df_matches = pd.read_csv(file2_path)
print('done')
# Out:
# done

# %%
# EDA
df_matches.head(2)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 1    Chennai Super Kings   runs           33.0        241.0          20.0
#
#   super_over method    umpire1      umpire2
# 0          N    NaN  Asad Rauf  RE Koertzen
# 1          N    NaN  MR Benson   SL Shastri

# %%
df_deliveries.head(2)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN

# %%
df_matches.shape
# Out:
# (1095, 20)

# %%
df_deliveries.shape
# Out:
# (260920, 17)

# %%
df_matches.info
# Out:
# <bound method DataFrame.info of            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 0                                 M Chinnaswamy Stadium
# 1            Punjab Cricket Association Stadium, Mohali
# 2                                      Feroz Shah Kotla
# 3                                      Wankhede Stadium
# 4                                          Eden Gardens
# ...                                                 ...
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                        team2  \
# 0     Royal Challengers Bangalore        Kolkata Knight Riders
# 1                 Kings XI Punjab          Chennai Super Kings
# 2                Delhi Daredevils             Rajasthan Royals
# 3                  Mumbai Indians  Royal Challengers Bangalore
# 4           Kolkata Knight Riders              Deccan Chargers
# ...                           ...                          ...
# 1090                 Punjab Kings          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092  Royal Challengers Bengaluru             Rajasthan Royals
# 1093          Sunrisers Hyderabad             Rajasthan Royals
# 1094          Sunrisers Hyderabad        Kolkata Knight Riders
#
#                       toss_winner toss_decision                       winner  \
# 0     Royal Challengers Bangalore         field        Kolkata Knight Riders
# 1             Chennai Super Kings           bat          Chennai Super Kings
# 2                Rajasthan Royals           bat             Delhi Daredevils
# 3                  Mumbai Indians           bat  Royal Challengers Bangalore
# 4                 Deccan Chargers           bat        Kolkata Knight Riders
# ...                           ...           ...                          ...
# 1090                 Punjab Kings           bat          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad           bat        Kolkata Knight Riders
# 1092             Rajasthan Royals         field             Rajasthan Royals
# 1093             Rajasthan Royals         field          Sunrisers Hyderabad
# 1094          Sunrisers Hyderabad           bat        Kolkata Knight Riders
#
#        result  result_margin  target_runs  target_overs super_over method  \
# 0        runs          140.0        223.0          20.0          N    NaN
# 1        runs           33.0        241.0          20.0          N    NaN
# 2     wickets            9.0        130.0          20.0          N    NaN
# 3     wickets            5.0        166.0          20.0          N    NaN
# 4     wickets            5.0        111.0          20.0          N    NaN
# ...       ...            ...          ...           ...        ...    ...
# 1090  wickets            4.0        215.0          20.0          N    NaN
# 1091  wickets            8.0        160.0          20.0          N    NaN
# 1092  wickets            4.0        173.0          20.0          N    NaN
# 1093     runs           36.0        176.0          20.0          N    NaN
# 1094  wickets            8.0        114.0          20.0          N    NaN
#
#                     umpire1               umpire2
# 0                 Asad Rauf           RE Koertzen
# 1                 MR Benson            SL Shastri
# 2                 Aleem Dar        GA Pratapkumar
# 3                  SJ Davis             DJ Harper
# 4                 BF Bowden           K Hariharan
# ...                     ...                   ...
# 1090            Nitin Menon             VK Sharma
# 1091           AK Chaudhary              R Pandit
# 1092  KN Ananthapadmanabhan  MV Saidharshan Kumar
# 1093            Nitin Menon             VK Sharma
# 1094          J Madanagopal           Nitin Menon
#
# [1095 rows x 20 columns]>

# %%
df_matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
# COUNT OF NULL VALUES
df_matches.isna().sum().sort_values(ascending = False)
# Out:
# method             1074
# city                 51
# result_margin        19
# player_of_match       5
# winner                5
# target_runs           3
# target_overs          3
# id                    0
# date                  0
# season                0
# venue                 0
# match_type            0
# toss_decision         0
# toss_winner           0
# team2                 0
# team1                 0
# result                0
# super_over            0
# umpire1               0
# umpire2               0
# dtype: int64

# %%
sns.heatmap(df_matches.isna())
plt.show()

# %%
# PERCENTAGE OF NULL VALUES
df_matches.isna().mean().sort_values(ascending = False)*100
# if 5% se data kam hai to we can delete the data
# Out:
# method             98.082192
# city                4.657534
# result_margin       1.735160
# player_of_match     0.456621
# winner              0.456621
# target_runs         0.273973
# target_overs        0.273973
# id                  0.000000
# date                0.000000
# season              0.000000
# venue               0.000000
# match_type          0.000000
# toss_decision       0.000000
# toss_winner         0.000000
# team2               0.000000
# team1               0.000000
# result              0.000000
# super_over          0.000000
# umpire1             0.000000
# umpire2             0.000000
# dtype: float64

# %%
df_matches['method'].value_counts()
''' according to the analysis D/L method is called in the situations of rain 
etc so the other matches which were carried out were normally played 
so we will fill the null values with normal '''
# Out:
# ' according to the analysis D/L method is called in the situations of rain \netc so the other matches which were carried out were normally played \nso we will fill the null values with normal '

# %%
df_matches['method'].fillna('Normal Method', inplace = True)
print('done')
# Out:
# done
# C:\Users\HP\AppData\Local\Temp\ipykernel_16704\3297482681.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_matches['method'].fillna('Normal Method', inplace = True)

# %%
df_matches.isna().mean().sort_values(ascending = False)*100
# Out:
# city               4.657534
# result_margin      1.735160
# player_of_match    0.456621
# winner             0.456621
# target_overs       0.273973
# target_runs        0.273973
# id                 0.000000
# season             0.000000
# date               0.000000
# team1              0.000000
# venue              0.000000
# match_type         0.000000
# toss_decision      0.000000
# toss_winner        0.000000
# team2              0.000000
# result             0.000000
# super_over         0.000000
# method             0.000000
# umpire1            0.000000
# umpire2            0.000000
# dtype: float64

# %%
df_matches['city'].value_counts()
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Visakhapatnam      15
# Durban             15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Navi Mumbai         9
# Indore              9
# Johannesburg        8
# Ranchi              7
# Cuttack             7
# Cape Town           7
# Port Elizabeth      7
# Raipur              6
# Kochi               5
# Mohali              5
# Kanpur              4
# East London         3
# Kimberley           3
# Nagpur              3
# Guwahati            3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
df_matches[df_matches['city'].isna()]
# Out:
#           id   season city        date   match_type player_of_match  \
# 399   729281     2014  NaN  2014-04-17       League       YS Chahal
# 402   729287     2014  NaN  2014-04-19       League        PA Patel
# 403   729289     2014  NaN  2014-04-19       League       JP Duminy
# 404   729291     2014  NaN  2014-04-20       League      GJ Maxwell
# 406   729295     2014  NaN  2014-04-22       League      GJ Maxwell
# 407   729297     2014  NaN  2014-04-23       League       RA Jadeja
# 408   729299     2014  NaN  2014-04-24       League         CA Lynn
# 409   729301     2014  NaN  2014-04-25       League        AJ Finch
# 410   729303     2014  NaN  2014-04-25       League       MM Sharma
# 413   729309     2014  NaN  2014-04-27       League         M Vijay
# 414   729311     2014  NaN  2014-04-27       League        DR Smith
# 415   729313     2014  NaN  2014-04-28       League  Sandeep Sharma
# 417   729317     2014  NaN  2014-04-30       League         B Kumar
# 757  1216493  2020/21  NaN  2020-09-20       League      MP Stoinis
# 758  1216534  2020/21  NaN  2020-09-21       League       YS Chahal
# 759  1216496  2020/21  NaN  2020-09-22       League       SV Samson
# 761  1216510  2020/21  NaN  2020-09-24       League        KL Rahul
# 762  1216539  2020/21  NaN  2020-09-25       League         PP Shaw
# 764  1216527  2020/21  NaN  2020-09-27       League       SV Samson
# 765  1216547  2020/21  NaN  2020-09-28       League  AB de Villiers
# 767  1216504  2020/21  NaN  2020-09-30       League     Shivam Mavi
# 769  1216516  2020/21  NaN  2020-10-02       League         PK Garg
# 771  1216515  2020/21  NaN  2020-10-03       League         SS Iyer
# 772  1216513  2020/21  NaN  2020-10-04       League       SR Watson
# 773  1216538  2020/21  NaN  2020-10-04       League        TA Boult
# 774  1216519  2020/21  NaN  2020-10-05       League        AR Patel
# 777  1216542  2020/21  NaN  2020-10-08       League     JM Bairstow
# 778  1216500  2020/21  NaN  2020-10-09       League        R Ashwin
# 780  1216525  2020/21  NaN  2020-10-10       League         V Kohli
# 781  1216507  2020/21  NaN  2020-10-11       League       R Tewatia
# 783  1216540  2020/21  NaN  2020-10-12       League  AB de Villiers
# 784  1216528  2020/21  NaN  2020-10-13       League       RA Jadeja
# 785  1216543  2020/21  NaN  2020-10-14       League        A Nortje
# 786  1216531  2020/21  NaN  2020-10-15       League        KL Rahul
# 788  1216509  2020/21  NaN  2020-10-17       League        S Dhawan
# 789  1216522  2020/21  NaN  2020-10-17       League  AB de Villiers
# 791  1216517  2020/21  NaN  2020-10-18       League        KL Rahul
# 793  1216546  2020/21  NaN  2020-10-20       League        S Dhawan
# 795  1216518  2020/21  NaN  2020-10-22       League       MK Pandey
# 796  1216521  2020/21  NaN  2020-10-23       League        TA Boult
# 798  1216498  2020/21  NaN  2020-10-24       League       CJ Jordan
# 800  1216544  2020/21  NaN  2020-10-25       League      RD Gaikwad
# 801  1216520  2020/21  NaN  2020-10-26       League        CH Gayle
# 802  1216524  2020/21  NaN  2020-10-27       League         WP Saha
# 804  1216536  2020/21  NaN  2020-10-29       League      RD Gaikwad
# 806  1216502  2020/21  NaN  2020-10-31       League  Sandeep Sharma
# 807  1216535  2020/21  NaN  2020-10-31       League    Ishan Kishan
# 809  1216530  2020/21  NaN  2020-11-01       League      PJ Cummins
# 811  1216495  2020/21  NaN  2020-11-03       League        S Nadeem
# 812  1237177  2020/21  NaN  2020-11-05  Qualifier 1       JJ Bumrah
# 815  1237181  2020/21  NaN  2020-11-10        Final        TA Boult
#
#                                    venue                        team1  \
# 399              Sharjah Cricket Stadium             Delhi Daredevils
# 402  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 403  Dubai International Cricket Stadium        Kolkata Knight Riders
# 404              Sharjah Cricket Stadium             Rajasthan Royals
# 406              Sharjah Cricket Stadium              Kings XI Punjab
# 407  Dubai International Cricket Stadium             Rajasthan Royals
# 408              Sharjah Cricket Stadium  Royal Challengers Bangalore
# 409  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 410  Dubai International Cricket Stadium          Chennai Super Kings
# 413              Sharjah Cricket Stadium             Delhi Daredevils
# 414              Sharjah Cricket Stadium          Sunrisers Hyderabad
# 415  Dubai International Cricket Stadium              Kings XI Punjab
# 417  Dubai International Cricket Stadium               Mumbai Indians
# 757  Dubai International Cricket Stadium               Delhi Capitals
# 758  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 759              Sharjah Cricket Stadium             Rajasthan Royals
# 761  Dubai International Cricket Stadium              Kings XI Punjab
# 762  Dubai International Cricket Stadium               Delhi Capitals
# 764              Sharjah Cricket Stadium              Kings XI Punjab
# 765  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 767  Dubai International Cricket Stadium        Kolkata Knight Riders
# 769  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 771              Sharjah Cricket Stadium               Delhi Capitals
# 772  Dubai International Cricket Stadium              Kings XI Punjab
# 773              Sharjah Cricket Stadium               Mumbai Indians
# 774  Dubai International Cricket Stadium               Delhi Capitals
# 777  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 778              Sharjah Cricket Stadium               Delhi Capitals
# 780  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 781  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 783              Sharjah Cricket Stadium  Royal Challengers Bangalore
# 784  Dubai International Cricket Stadium          Chennai Super Kings
# 785  Dubai International Cricket Stadium               Delhi Capitals
# 786              Sharjah Cricket Stadium  Royal Challengers Bangalore
# 788              Sharjah Cricket Stadium          Chennai Super Kings
# 789  Dubai International Cricket Stadium             Rajasthan Royals
# 791  Dubai International Cricket Stadium               Mumbai Indians
# 793  Dubai International Cricket Stadium               Delhi Capitals
# 795  Dubai International Cricket Stadium             Rajasthan Royals
# 796              Sharjah Cricket Stadium          Chennai Super Kings
# 798  Dubai International Cricket Stadium              Kings XI Punjab
# 800  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 801              Sharjah Cricket Stadium        Kolkata Knight Riders
# 802  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 804  Dubai International Cricket Stadium        Kolkata Knight Riders
# 806              Sharjah Cricket Stadium  Royal Challengers Bangalore
# 807  Dubai International Cricket Stadium               Delhi Capitals
# 809  Dubai International Cricket Stadium        Kolkata Knight Riders
# 811              Sharjah Cricket Stadium               Mumbai Indians
# 812  Dubai International Cricket Stadium               Mumbai Indians
# 815  Dubai International Cricket Stadium               Delhi Capitals
#
#                            team2                  toss_winner toss_decision  \
# 399  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 402               Mumbai Indians  Royal Challengers Bangalore         field
# 403             Delhi Daredevils        Kolkata Knight Riders           bat
# 404              Kings XI Punjab              Kings XI Punjab         field
# 406          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 407          Chennai Super Kings             Rajasthan Royals         field
# 408        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 409             Delhi Daredevils          Sunrisers Hyderabad           bat
# 410               Mumbai Indians               Mumbai Indians           bat
# 413               Mumbai Indians               Mumbai Indians           bat
# 414          Chennai Super Kings          Sunrisers Hyderabad           bat
# 415  Royal Challengers Bangalore              Kings XI Punjab         field
# 417          Sunrisers Hyderabad               Mumbai Indians         field
# 757              Kings XI Punjab              Kings XI Punjab         field
# 758          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 759          Chennai Super Kings          Chennai Super Kings         field
# 761  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 762          Chennai Super Kings          Chennai Super Kings         field
# 764             Rajasthan Royals             Rajasthan Royals         field
# 765               Mumbai Indians               Mumbai Indians         field
# 767             Rajasthan Royals             Rajasthan Royals         field
# 769          Chennai Super Kings          Sunrisers Hyderabad           bat
# 771        Kolkata Knight Riders        Kolkata Knight Riders         field
# 772          Chennai Super Kings              Kings XI Punjab           bat
# 773          Sunrisers Hyderabad               Mumbai Indians           bat
# 774  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 777              Kings XI Punjab          Sunrisers Hyderabad           bat
# 778             Rajasthan Royals             Rajasthan Royals         field
# 780          Chennai Super Kings  Royal Challengers Bangalore           bat
# 781             Rajasthan Royals          Sunrisers Hyderabad           bat
# 783        Kolkata Knight Riders  Royal Challengers Bangalore           bat
# 784          Sunrisers Hyderabad          Chennai Super Kings           bat
# 785             Rajasthan Royals               Delhi Capitals           bat
# 786              Kings XI Punjab  Royal Challengers Bangalore           bat
# 788               Delhi Capitals          Chennai Super Kings           bat
# 789  Royal Challengers Bangalore             Rajasthan Royals           bat
# 791              Kings XI Punjab               Mumbai Indians           bat
# 793              Kings XI Punjab               Delhi Capitals           bat
# 795          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 796               Mumbai Indians               Mumbai Indians         field
# 798          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 800          Chennai Super Kings  Royal Challengers Bangalore           bat
# 801              Kings XI Punjab              Kings XI Punjab         field
# 802               Delhi Capitals               Delhi Capitals         field
# 804          Chennai Super Kings          Chennai Super Kings         field
# 806          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 807               Mumbai Indians               Mumbai Indians         field
# 809             Rajasthan Royals             Rajasthan Royals         field
# 811          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 812               Delhi Capitals               Delhi Capitals         field
# 815               Mumbai Indians               Delhi Capitals           bat
#
#                           winner   result  result_margin  target_runs  \
# 399  Royal Challengers Bangalore  wickets            8.0        146.0
# 402  Royal Challengers Bangalore  wickets            7.0        116.0
# 403             Delhi Daredevils  wickets            4.0        167.0
# 404              Kings XI Punjab  wickets            7.0        192.0
# 406              Kings XI Punjab     runs           72.0        194.0
# 407          Chennai Super Kings     runs            7.0        141.0
# 408        Kolkata Knight Riders     runs            2.0        151.0
# 409          Sunrisers Hyderabad     runs            4.0        185.0
# 410          Chennai Super Kings  wickets            7.0        142.0
# 413             Delhi Daredevils  wickets            6.0        126.0
# 414          Chennai Super Kings  wickets            5.0        146.0
# 415              Kings XI Punjab  wickets            5.0        125.0
# 417          Sunrisers Hyderabad     runs           15.0        173.0
# 757               Delhi Capitals      tie            NaN        158.0
# 758  Royal Challengers Bangalore     runs           10.0        164.0
# 759             Rajasthan Royals     runs           16.0        217.0
# 761              Kings XI Punjab     runs           97.0        207.0
# 762               Delhi Capitals     runs           44.0        176.0
# 764             Rajasthan Royals  wickets            4.0        224.0
# 765  Royal Challengers Bangalore      tie            NaN        202.0
# 767        Kolkata Knight Riders     runs           37.0        175.0
# 769          Sunrisers Hyderabad     runs            7.0        165.0
# 771               Delhi Capitals     runs           18.0        229.0
# 772          Chennai Super Kings  wickets           10.0        179.0
# 773               Mumbai Indians     runs           34.0        209.0
# 774               Delhi Capitals     runs           59.0        197.0
# 777          Sunrisers Hyderabad     runs           69.0        202.0
# 778               Delhi Capitals     runs           46.0        185.0
# 780  Royal Challengers Bangalore     runs           37.0        170.0
# 781             Rajasthan Royals  wickets            5.0        159.0
# 783  Royal Challengers Bangalore     runs           82.0        195.0
# 784          Chennai Super Kings     runs           20.0        168.0
# 785               Delhi Capitals     runs           13.0        162.0
# 786              Kings XI Punjab  wickets            8.0        172.0
# 788               Delhi Capitals  wickets            5.0        180.0
# 789  Royal Challengers Bangalore  wickets            7.0        178.0
# 791              Kings XI Punjab      tie            NaN        177.0
# 793              Kings XI Punjab  wickets            5.0        165.0
# 795          Sunrisers Hyderabad  wickets            8.0        155.0
# 796               Mumbai Indians  wickets           10.0        115.0
# 798              Kings XI Punjab     runs           12.0        127.0
# 800          Chennai Super Kings  wickets            8.0        146.0
# 801              Kings XI Punjab  wickets            8.0        150.0
# 802          Sunrisers Hyderabad     runs           88.0        220.0
# 804          Chennai Super Kings  wickets            6.0        173.0
# 806          Sunrisers Hyderabad  wickets            5.0        121.0
# 807               Mumbai Indians  wickets            9.0        111.0
# 809        Kolkata Knight Riders     runs           60.0        192.0
# 811          Sunrisers Hyderabad  wickets           10.0        150.0
# 812               Mumbai Indians     runs           57.0        201.0
# 815               Mumbai Indians  wickets            5.0        157.0
#
#      target_overs super_over         method                umpire1  \
# 399          20.0          N  Normal Method              Aleem Dar
# 402          20.0          N  Normal Method              Aleem Dar
# 403          20.0          N  Normal Method              Aleem Dar
# 404          20.0          N  Normal Method              BF Bowden
# 406          20.0          N  Normal Method              M Erasmus
# 407          20.0          N  Normal Method        HDPK Dharmasena
# 408          20.0          N  Normal Method              Aleem Dar
# 409          20.0          N  Normal Method              M Erasmus
# 410          20.0          N  Normal Method              BF Bowden
# 413          20.0          N  Normal Method              Aleem Dar
# 414          20.0          N  Normal Method           AK Chaudhary
# 415          20.0          N  Normal Method              BF Bowden
# 417          20.0          N  Normal Method        HDPK Dharmasena
# 757          20.0          Y  Normal Method           AK Chaudhary
# 758          20.0          N  Normal Method            AY Dandekar
# 759          20.0          N  Normal Method          C Shamshuddin
# 761          20.0          N  Normal Method           AK Chaudhary
# 762          20.0          N  Normal Method  KN Ananthapadmanabhan
# 764          20.0          N  Normal Method         RK Illingworth
# 765          20.0          Y  Normal Method            Nitin Menon
# 767          20.0          N  Normal Method  KN Ananthapadmanabhan
# 769          20.0          N  Normal Method           AK Chaudhary
# 771          20.0          N  Normal Method            VA Kulkarni
# 772          20.0          N  Normal Method            AY Dandekar
# 773          20.0          N  Normal Method  KN Ananthapadmanabhan
# 774          20.0          N  Normal Method            Nitin Menon
# 777          20.0          N  Normal Method           AK Chaudhary
# 778          20.0          N  Normal Method  KN Ananthapadmanabhan
# 780          20.0          N  Normal Method           AK Chaudhary
# 781          20.0          N  Normal Method               YC Barde
# 783          20.0          N  Normal Method         RK Illingworth
# 784          20.0          N  Normal Method           AK Chaudhary
# 785          20.0          N  Normal Method           AK Chaudhary
# 786          20.0          N  Normal Method  KN Ananthapadmanabhan
# 788          20.0          N  Normal Method  KN Ananthapadmanabhan
# 789          20.0          N  Normal Method           AK Chaudhary
# 791          20.0          Y  Normal Method            Nitin Menon
# 793          20.0          N  Normal Method          C Shamshuddin
# 795          20.0          N  Normal Method            Nitin Menon
# 796          20.0          N  Normal Method          C Shamshuddin
# 798          20.0          N  Normal Method            AY Dandekar
# 800          20.0          N  Normal Method          C Shamshuddin
# 801          20.0          N  Normal Method  KN Ananthapadmanabhan
# 802          20.0          N  Normal Method           AK Chaudhary
# 804          20.0          N  Normal Method          C Shamshuddin
# 806          20.0          N  Normal Method  KN Ananthapadmanabhan
# 807          20.0          N  Normal Method               YC Barde
# 809          20.0          N  Normal Method            Nitin Menon
# 811          20.0          N  Normal Method          C Shamshuddin
# 812          20.0          N  Normal Method            CB Gaffaney
# 815          20.0          N  Normal Method            CB Gaffaney
#
#             umpire2
# 399          S Ravi
# 402    AK Chaudhary
# 403     VA Kulkarni
# 404       M Erasmus
# 406          S Ravi
# 407  RK Illingworth
# 408     VA Kulkarni
# 409          S Ravi
# 410       M Erasmus
# 413     VA Kulkarni
# 414     VA Kulkarni
# 415          S Ravi
# 417       M Erasmus
# 757     Nitin Menon
# 758     Nitin Menon
# 759     VA Kulkarni
# 761      PR Reiffel
# 762  RK Illingworth
# 764    K Srinivasan
# 765      PR Reiffel
# 767   C Shamshuddin
# 769      PR Reiffel
# 771  RK Illingworth
# 772     Nitin Menon
# 773  RK Illingworth
# 774        YC Barde
# 777     Nitin Menon
# 778   C Shamshuddin
# 780      PR Reiffel
# 781      PR Reiffel
# 783    K Srinivasan
# 784      PR Reiffel
# 785     Nitin Menon
# 786   C Shamshuddin
# 788  RK Illingworth
# 789     Nitin Menon
# 791      PR Reiffel
# 793  RK Illingworth
# 795      PR Reiffel
# 796     VA Kulkarni
# 798      PR Reiffel
# 800  RK Illingworth
# 801  RK Illingworth
# 802     Nitin Menon
# 804  RK Illingworth
# 806    K Srinivasan
# 807      PR Reiffel
# 809      PR Reiffel
# 811  RK Illingworth
# 812     Nitin Menon
# 815     Nitin Menon

# %%
df_matches['city'].fillna('UAE',inplace = True)
print('done')
#inspace is used to make the changes permanent
# Out:
# done
# C:\Users\HP\AppData\Local\Temp\ipykernel_16704\1778975506.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_matches['city'].fillna('UAE',inplace = True)

# %%
df_matches.isna().mean().sort_values(ascending = False)*100
# Out:
# result_margin      1.735160
# player_of_match    0.456621
# winner             0.456621
# target_runs        0.273973
# target_overs       0.273973
# city               0.000000
# season             0.000000
# id                 0.000000
# date               0.000000
# team1              0.000000
# venue              0.000000
# match_type         0.000000
# toss_decision      0.000000
# toss_winner        0.000000
# team2              0.000000
# result             0.000000
# super_over         0.000000
# method             0.000000
# umpire1            0.000000
# umpire2            0.000000
# dtype: float64

# %%
df_matches[df_matches['result_margin'].isna()]
# Out:
#           id   season       city        date match_type player_of_match  \
# 66    392190     2009  Cape Town  2009-04-23     League       YK Pathan
# 130   419121  2009/10    Chennai  2010-03-21     League        J Theron
# 241   501265     2011      Delhi  2011-05-21     League             NaN
# 328   598004     2013  Hyderabad  2013-04-07     League       GH Vihari
# 342   598017     2013  Bangalore  2013-04-16     League         V Kohli
# 416   729315     2014  Abu Dhabi  2014-04-29     League     JP Faulkner
# 475   829741     2015  Ahmedabad  2015-04-21     League        SE Marsh
# 485   829763     2015  Bangalore  2015-04-29     League             NaN
# 511   829813     2015  Bangalore  2015-05-17     League             NaN
# 610  1082625     2017     Rajkot  2017-04-29     League       KH Pandya
# 705  1175365     2019      Delhi  2019-03-30     League         PP Shaw
# 744  1178424     2019  Bengaluru  2019-04-30     League             NaN
# 746  1178426     2019     Mumbai  2019-05-02     League       JJ Bumrah
# 757  1216493  2020/21        UAE  2020-09-20     League      MP Stoinis
# 765  1216547  2020/21        UAE  2020-09-28     League  AB de Villiers
# 790  1216512  2020/21  Abu Dhabi  2020-10-18     League     LH Ferguson
# 791  1216517  2020/21        UAE  2020-10-18     League        KL Rahul
# 835  1254077     2021    Chennai  2021-04-25     League         PP Shaw
# 994  1359519     2023    Lucknow  2023-05-03     League             NaN
#
#                                                  venue  \
# 66                                            Newlands
# 130                    MA Chidambaram Stadium, Chepauk
# 241                                   Feroz Shah Kotla
# 328          Rajiv Gandhi International Stadium, Uppal
# 342                              M Chinnaswamy Stadium
# 416                               Sheikh Zayed Stadium
# 475                       Sardar Patel Stadium, Motera
# 485                              M Chinnaswamy Stadium
# 511                              M Chinnaswamy Stadium
# 610             Saurashtra Cricket Association Stadium
# 705                               Arun Jaitley Stadium
# 744                              M.Chinnaswamy Stadium
# 746                                   Wankhede Stadium
# 757                Dubai International Cricket Stadium
# 765                Dubai International Cricket Stadium
# 790                               Sheikh Zayed Stadium
# 791                Dubai International Cricket Stadium
# 835           MA Chidambaram Stadium, Chepauk, Chennai
# 994  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
#
#                            team1                        team2  \
# 66         Kolkata Knight Riders             Rajasthan Royals
# 130          Chennai Super Kings              Kings XI Punjab
# 241             Delhi Daredevils                Pune Warriors
# 328          Sunrisers Hyderabad  Royal Challengers Bangalore
# 342  Royal Challengers Bangalore             Delhi Daredevils
# 416        Kolkata Knight Riders             Rajasthan Royals
# 475             Rajasthan Royals              Kings XI Punjab
# 485  Royal Challengers Bangalore             Rajasthan Royals
# 511  Royal Challengers Bangalore             Delhi Daredevils
# 610                Gujarat Lions               Mumbai Indians
# 705        Kolkata Knight Riders               Delhi Capitals
# 744  Royal Challengers Bangalore             Rajasthan Royals
# 746               Mumbai Indians          Sunrisers Hyderabad
# 757               Delhi Capitals              Kings XI Punjab
# 765  Royal Challengers Bangalore               Mumbai Indians
# 790        Kolkata Knight Riders          Sunrisers Hyderabad
# 791               Mumbai Indians              Kings XI Punjab
# 835               Delhi Capitals          Sunrisers Hyderabad
# 994         Lucknow Super Giants          Chennai Super Kings
#
#                      toss_winner toss_decision                       winner  \
# 66         Kolkata Knight Riders         field             Rajasthan Royals
# 130          Chennai Super Kings         field              Kings XI Punjab
# 241             Delhi Daredevils           bat                          NaN
# 328  Royal Challengers Bangalore           bat          Sunrisers Hyderabad
# 342  Royal Challengers Bangalore         field  Royal Challengers Bangalore
# 416             Rajasthan Royals           bat             Rajasthan Royals
# 475              Kings XI Punjab         field              Kings XI Punjab
# 485             Rajasthan Royals         field                          NaN
# 511  Royal Challengers Bangalore         field                          NaN
# 610                Gujarat Lions           bat               Mumbai Indians
# 705               Delhi Capitals         field               Delhi Capitals
# 744             Rajasthan Royals         field                          NaN
# 746               Mumbai Indians           bat               Mumbai Indians
# 757              Kings XI Punjab         field               Delhi Capitals
# 765               Mumbai Indians         field  Royal Challengers Bangalore
# 790          Sunrisers Hyderabad         field        Kolkata Knight Riders
# 791               Mumbai Indians           bat              Kings XI Punjab
# 835               Delhi Capitals           bat               Delhi Capitals
# 994          Chennai Super Kings         field                          NaN
#
#         result  result_margin  target_runs  target_overs super_over  \
# 66         tie            NaN        151.0          20.0          Y
# 130        tie            NaN        137.0          20.0          Y
# 241  no result            NaN          NaN           NaN          N
# 328        tie            NaN        131.0          20.0          Y
# 342        tie            NaN        153.0          20.0          Y
# 416        tie            NaN        153.0          20.0          Y
# 475        tie            NaN        192.0          20.0          Y
# 485  no result            NaN          NaN           NaN          N
# 511  no result            NaN        188.0          20.0          N
# 610        tie            NaN        154.0          20.0          Y
# 705        tie            NaN        186.0          20.0          Y
# 744  no result            NaN         63.0           5.0          N
# 746        tie            NaN        163.0          20.0          Y
# 757        tie            NaN        158.0          20.0          Y
# 765        tie            NaN        202.0          20.0          Y
# 790        tie            NaN        164.0          20.0          Y
# 791        tie            NaN        177.0          20.0          Y
# 835        tie            NaN        160.0          20.0          Y
# 994  no result            NaN          NaN           NaN          N
#
#             method          umpire1                umpire2
# 66   Normal Method        MR Benson              M Erasmus
# 130  Normal Method      K Hariharan              DJ Harper
# 241  Normal Method        SS Hazare              RJ Tucker
# 328  Normal Method     AK Chaudhary                 S Ravi
# 342  Normal Method        M Erasmus            VA Kulkarni
# 416  Normal Method        Aleem Dar           AK Chaudhary
# 475  Normal Method        M Erasmus                 S Ravi
# 485  Normal Method        JD Cloete              PG Pathak
# 511  Normal Method  HDPK Dharmasena           K Srinivasan
# 610  Normal Method     AK Chaudhary            CB Gaffaney
# 705  Normal Method      AY Dandekar            Nitin Menon
# 744  Normal Method         NJ Llong              UV Gandhe
# 746  Normal Method        CK Nandan                 S Ravi
# 757  Normal Method     AK Chaudhary            Nitin Menon
# 765  Normal Method      Nitin Menon             PR Reiffel
# 790  Normal Method        PG Pathak                 S Ravi
# 791  Normal Method      Nitin Menon             PR Reiffel
# 835  Normal Method      CB Gaffaney  KN Ananthapadmanabhan
# 994  Normal Method     AK Chaudhary          NA Patwardhan

# %%
df_matches['result_margin'].info
# Out:
# <bound method Series.info of 0       140.0
# 1        33.0
# 2         9.0
# 3         5.0
# 4         5.0
#         ...
# 1090      4.0
# 1091      8.0
# 1092      4.0
# 1093     36.0
# 1094      8.0
# Name: result_margin, Length: 1095, dtype: float64>

# %%
df_matches['result_margin'].fillna(0,inplace = True)
print('done')
# Out:
# done

# %%
df_matches.isna().mean().sort_values(ascending = False)*100
# Out:
# winner             0.456621
# player_of_match    0.456621
# target_overs       0.273973
# target_runs        0.273973
# date               0.000000
# city               0.000000
# season             0.000000
# id                 0.000000
# team1              0.000000
# team2              0.000000
# venue              0.000000
# match_type         0.000000
# toss_decision      0.000000
# toss_winner        0.000000
# result_margin      0.000000
# result             0.000000
# super_over         0.000000
# method             0.000000
# umpire1            0.000000
# umpire2            0.000000
# dtype: float64

# %%
# winner
# player_of_match
# target_overs
# target_runs

# %%
df_matches[df_matches['winner'].isna()]
# Out:
#           id season       city        date match_type player_of_match  \
# 241   501265   2011      Delhi  2011-05-21     League             NaN
# 485   829763   2015  Bangalore  2015-04-29     League             NaN
# 511   829813   2015  Bangalore  2015-05-17     League             NaN
# 744  1178424   2019  Bengaluru  2019-04-30     League             NaN
# 994  1359519   2023    Lucknow  2023-05-03     League             NaN
#
#                                                  venue  \
# 241                                   Feroz Shah Kotla
# 485                              M Chinnaswamy Stadium
# 511                              M Chinnaswamy Stadium
# 744                              M.Chinnaswamy Stadium
# 994  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
#
#                            team1                team2  \
# 241             Delhi Daredevils        Pune Warriors
# 485  Royal Challengers Bangalore     Rajasthan Royals
# 511  Royal Challengers Bangalore     Delhi Daredevils
# 744  Royal Challengers Bangalore     Rajasthan Royals
# 994         Lucknow Super Giants  Chennai Super Kings
#
#                      toss_winner toss_decision winner     result  \
# 241             Delhi Daredevils           bat    NaN  no result
# 485             Rajasthan Royals         field    NaN  no result
# 511  Royal Challengers Bangalore         field    NaN  no result
# 744             Rajasthan Royals         field    NaN  no result
# 994          Chennai Super Kings         field    NaN  no result
#
#      result_margin  target_runs  target_overs super_over         method  \
# 241            0.0          NaN           NaN          N  Normal Method
# 485            0.0          NaN           NaN          N  Normal Method
# 511            0.0        188.0          20.0          N  Normal Method
# 744            0.0         63.0           5.0          N  Normal Method
# 994            0.0          NaN           NaN          N  Normal Method
#
#              umpire1        umpire2
# 241        SS Hazare      RJ Tucker
# 485        JD Cloete      PG Pathak
# 511  HDPK Dharmasena   K Srinivasan
# 744         NJ Llong      UV Gandhe
# 994     AK Chaudhary  NA Patwardhan

# %%
# filling multiple columns at a time
df_matches.fillna({'winner':'No Winners','player_of_match':'No player of match'}, inplace = True)
print('done')
# Out:
# done

# %%
df_matches.isna().mean().sort_values(ascending = False)*100
# Out:
# target_overs       0.273973
# target_runs        0.273973
# id                 0.000000
# season             0.000000
# date               0.000000
# city               0.000000
# match_type         0.000000
# player_of_match    0.000000
# team2              0.000000
# toss_winner        0.000000
# venue              0.000000
# team1              0.000000
# winner             0.000000
# toss_decision      0.000000
# result_margin      0.000000
# result             0.000000
# super_over         0.000000
# method             0.000000
# umpire1            0.000000
# umpire2            0.000000
# dtype: float64

# %%
df_matches[df_matches['target_runs'].isna()]
# Out:
#           id season       city        date match_type     player_of_match  \
# 241   501265   2011      Delhi  2011-05-21     League  No player of match
# 485   829763   2015  Bangalore  2015-04-29     League  No player of match
# 994  1359519   2023    Lucknow  2023-05-03     League  No player of match
#
#                                                  venue  \
# 241                                   Feroz Shah Kotla
# 485                              M Chinnaswamy Stadium
# 994  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
#
#                            team1                team2          toss_winner  \
# 241             Delhi Daredevils        Pune Warriors     Delhi Daredevils
# 485  Royal Challengers Bangalore     Rajasthan Royals     Rajasthan Royals
# 994         Lucknow Super Giants  Chennai Super Kings  Chennai Super Kings
#
#     toss_decision      winner     result  result_margin  target_runs  \
# 241           bat  No Winners  no result            0.0          NaN
# 485         field  No Winners  no result            0.0          NaN
# 994         field  No Winners  no result            0.0          NaN
#
#      target_overs super_over         method       umpire1        umpire2
# 241           NaN          N  Normal Method     SS Hazare      RJ Tucker
# 485           NaN          N  Normal Method     JD Cloete      PG Pathak
# 994           NaN          N  Normal Method  AK Chaudhary  NA Patwardhan

# %%
df_matches.fillna({'target_runs':0,	'target_overs':0}, inplace = True)
print('done')

#another way
# df_matches.fillna(0,inplace = True) it will fill the only left nan columns
# Out:
# done

# %%
print('DATA HAS BEEN CLEANED')
# Out:
# DATA HAS BEEN CLEANED

# %%
df_matches.isna().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# match_type         0
# player_of_match    0
# venue              0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# target_runs        0
# target_overs       0
# super_over         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
sns.heatmap(df_matches.isna())
# Out:
# <Axes: >

# %%
df_matches['city'].value_counts()
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# UAE                51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Durban             15
# Visakhapatnam      15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Indore              9
# Navi Mumbai         9
# Johannesburg        8
# Ranchi              7
# Port Elizabeth      7
# Cuttack             7
# Cape Town           7
# Raipur              6
# Kochi               5
# Mohali              5
# Kanpur              4
# East London         3
# Kimberley           3
# Nagpur              3
# Guwahati            3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
data_rp = {'Navi Mumbai':'Mumbai',
           'Bengaluru':'Bangalore',
           'Sharjah':'UAE',
           'Abu Dhabi':'UAE','Kimberley':'Cape Town'}

df_matches.replace(data_rp, inplace = True)
print('done')
# Out:
# done

# %%
df_matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df_matches['city'].value_counts()
# Out:
# city
# Mumbai            182
# UAE                98
# Bangalore          94
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Chandigarh         61
# Jaipur             57
# Pune               51
# Ahmedabad          36
# Durban             15
# Visakhapatnam      15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Cape Town          10
# Rajkot             10
# Indore              9
# Johannesburg        8
# Ranchi              7
# Port Elizabeth      7
# Cuttack             7
# Raipur              6
# Kochi               5
# Mohali              5
# Kanpur              4
# Nagpur              3
# East London         3
# Guwahati            3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
df_matches.duplicated('id').value_counts()
# Out:
# False    1095
# Name: count, dtype: int64

# %%
df_matches.drop_duplicates('id', inplace = True)
print('done')
# Out:
# done

# %%
df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1095 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1095 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1095 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1095 non-null   float64
#  14  target_runs      1095 non-null   float64
#  15  target_overs     1095 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           1095 non-null   object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 171.2+ KB

# %%
# changing date columns datatype to date
df_matches['date']=pd.to_datetime(df_matches['date'])

# %%
df_matches['venue'].value_counts()
# Out:
# venue
# Eden Gardens                                                             77
# Wankhede Stadium                                                         73
# M Chinnaswamy Stadium                                                    65
# Feroz Shah Kotla                                                         60
# Rajiv Gandhi International Stadium, Uppal                                49
# MA Chidambaram Stadium, Chepauk                                          48
# Sawai Mansingh Stadium                                                   47
# Dubai International Cricket Stadium                                      46
# Wankhede Stadium, Mumbai                                                 45
# Punjab Cricket Association Stadium, Mohali                               35
# Sheikh Zayed Stadium                                                     29
# Sharjah Cricket Stadium                                                  28
# MA Chidambaram Stadium, Chepauk, Chennai                                 28
# Narendra Modi Stadium, Ahmedabad                                         24
# Maharashtra Cricket Association Stadium                                  22
# Dr DY Patil Sports Academy, Mumbai                                       20
# Dr DY Patil Sports Academy                                               17
# Brabourne Stadium, Mumbai                                                17
# Subrata Roy Sahara Stadium                                               16
# Eden Gardens, Kolkata                                                    16
# Arun Jaitley Stadium, Delhi                                              16
# Kingsmead                                                                15
# M.Chinnaswamy Stadium                                                    15
# Rajiv Gandhi International Stadium                                       15
# Arun Jaitley Stadium                                                     14
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow    14
# M Chinnaswamy Stadium, Bengaluru                                         14
# Rajiv Gandhi International Stadium, Uppal, Hyderabad                     13
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium                      13
# Maharashtra Cricket Association Stadium, Pune                            13
# SuperSport Park                                                          12
# Sardar Patel Stadium, Motera                                             12
# Punjab Cricket Association IS Bindra Stadium, Mohali                     11
# Sawai Mansingh Stadium, Jaipur                                           10
# Punjab Cricket Association IS Bindra Stadium                             10
# Saurashtra Cricket Association Stadium                                   10
# Brabourne Stadium                                                        10
# Himachal Pradesh Cricket Association Stadium                              9
# MA Chidambaram Stadium                                                    9
# Holkar Cricket Stadium                                                    9
# New Wanderers Stadium                                                     8
# Zayed Cricket Stadium, Abu Dhabi                                          8
# JSCA International Stadium Complex                                        7
# St George's Park                                                          7
# Barabati Stadium                                                          7
# Newlands                                                                  7
# Shaheed Veer Narayan Singh International Stadium                          6
# Nehru Stadium                                                             5
# Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur        5
# Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh          5
# Green Park                                                                4
# Himachal Pradesh Cricket Association Stadium, Dharamsala                  4
# De Beers Diamond Oval                                                     3
# Buffalo Park                                                              3
# Barsapara Cricket Stadium, Guwahati                                       3
# Vidarbha Cricket Association Stadium, Jamtha                              3
# OUTsurance Oval                                                           2
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam        2
# Name: count, dtype: int64

# %%
df_matches['venue'].str.split(',')
# Out:
# 0                                 [M Chinnaswamy Stadium]
# 1           [Punjab Cricket Association Stadium,  Mohali]
# 2                                      [Feroz Shah Kotla]
# 3                                      [Wankhede Stadium]
# 4                                          [Eden Gardens]
#                               ...
# 1090    [Rajiv Gandhi International Stadium,  Uppal,  ...
# 1091                  [Narendra Modi Stadium,  Ahmedabad]
# 1092                  [Narendra Modi Stadium,  Ahmedabad]
# 1093         [MA Chidambaram Stadium,  Chepauk,  Chennai]
# 1094         [MA Chidambaram Stadium,  Chepauk,  Chennai]
# Name: venue, Length: 1095, dtype: object

# %%
df_matches['venue'].apply(lambda row: row.title().split(',')[0])
# lambda : one liner anonymous func
# 1-1 row lega and sabse pehle lower case mein convert kardega
# Out:
# 0                    M Chinnaswamy Stadium
# 1       Punjab Cricket Association Stadium
# 2                         Feroz Shah Kotla
# 3                         Wankhede Stadium
# 4                             Eden Gardens
#                        ...
# 1090    Rajiv Gandhi International Stadium
# 1091                 Narendra Modi Stadium
# 1092                 Narendra Modi Stadium
# 1093                Ma Chidambaram Stadium
# 1094                Ma Chidambaram Stadium
# Name: venue, Length: 1095, dtype: object

# %%
df_matches['venue'].value_counts()
# Out:
# venue
# Eden Gardens                                                             77
# Wankhede Stadium                                                         73
# M Chinnaswamy Stadium                                                    65
# Feroz Shah Kotla                                                         60
# Rajiv Gandhi International Stadium, Uppal                                49
# MA Chidambaram Stadium, Chepauk                                          48
# Sawai Mansingh Stadium                                                   47
# Dubai International Cricket Stadium                                      46
# Wankhede Stadium, Mumbai                                                 45
# Punjab Cricket Association Stadium, Mohali                               35
# Sheikh Zayed Stadium                                                     29
# Sharjah Cricket Stadium                                                  28
# MA Chidambaram Stadium, Chepauk, Chennai                                 28
# Narendra Modi Stadium, Ahmedabad                                         24
# Maharashtra Cricket Association Stadium                                  22
# Dr DY Patil Sports Academy, Mumbai                                       20
# Dr DY Patil Sports Academy                                               17
# Brabourne Stadium, Mumbai                                                17
# Subrata Roy Sahara Stadium                                               16
# Eden Gardens, Kolkata                                                    16
# Arun Jaitley Stadium, Delhi                                              16
# Kingsmead                                                                15
# M.Chinnaswamy Stadium                                                    15
# Rajiv Gandhi International Stadium                                       15
# Arun Jaitley Stadium                                                     14
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow    14
# M Chinnaswamy Stadium, Bengaluru                                         14
# Rajiv Gandhi International Stadium, Uppal, Hyderabad                     13
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium                      13
# Maharashtra Cricket Association Stadium, Pune                            13
# SuperSport Park                                                          12
# Sardar Patel Stadium, Motera                                             12
# Punjab Cricket Association IS Bindra Stadium, Mohali                     11
# Sawai Mansingh Stadium, Jaipur                                           10
# Punjab Cricket Association IS Bindra Stadium                             10
# Saurashtra Cricket Association Stadium                                   10
# Brabourne Stadium                                                        10
# Himachal Pradesh Cricket Association Stadium                              9
# MA Chidambaram Stadium                                                    9
# Holkar Cricket Stadium                                                    9
# New Wanderers Stadium                                                     8
# Zayed Cricket Stadium, Abu Dhabi                                          8
# JSCA International Stadium Complex                                        7
# St George's Park                                                          7
# Barabati Stadium                                                          7
# Newlands                                                                  7
# Shaheed Veer Narayan Singh International Stadium                          6
# Nehru Stadium                                                             5
# Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur        5
# Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh          5
# Green Park                                                                4
# Himachal Pradesh Cricket Association Stadium, Dharamsala                  4
# De Beers Diamond Oval                                                     3
# Buffalo Park                                                              3
# Barsapara Cricket Stadium, Guwahati                                       3
# Vidarbha Cricket Association Stadium, Jamtha                              3
# OUTsurance Oval                                                           2
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam        2
# Name: count, dtype: int64

# %%
df_matches['venue'].value_counts().reset_index()
# Out:
#                                                 venue  count
# 0                                        Eden Gardens     77
# 1                                    Wankhede Stadium     73
# 2                               M Chinnaswamy Stadium     65
# 3                                    Feroz Shah Kotla     60
# 4           Rajiv Gandhi International Stadium, Uppal     49
# 5                     MA Chidambaram Stadium, Chepauk     48
# 6                              Sawai Mansingh Stadium     47
# 7                 Dubai International Cricket Stadium     46
# 8                            Wankhede Stadium, Mumbai     45
# 9          Punjab Cricket Association Stadium, Mohali     35
# 10                               Sheikh Zayed Stadium     29
# 11                            Sharjah Cricket Stadium     28
# 12           MA Chidambaram Stadium, Chepauk, Chennai     28
# 13                   Narendra Modi Stadium, Ahmedabad     24
# 14            Maharashtra Cricket Association Stadium     22
# 15                 Dr DY Patil Sports Academy, Mumbai     20
# 16                         Dr DY Patil Sports Academy     17
# 17                          Brabourne Stadium, Mumbai     17
# 18                         Subrata Roy Sahara Stadium     16
# 19                              Eden Gardens, Kolkata     16
# 20                        Arun Jaitley Stadium, Delhi     16
# 21                                          Kingsmead     15
# 22                              M.Chinnaswamy Stadium     15
# 23                 Rajiv Gandhi International Stadium     15
# 24                               Arun Jaitley Stadium     14
# 25  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...     14
# 26                   M Chinnaswamy Stadium, Bengaluru     14
# 27  Rajiv Gandhi International Stadium, Uppal, Hyd...     13
# 28  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...     13
# 29      Maharashtra Cricket Association Stadium, Pune     13
# 30                                    SuperSport Park     12
# 31                       Sardar Patel Stadium, Motera     12
# 32  Punjab Cricket Association IS Bindra Stadium, ...     11
# 33                     Sawai Mansingh Stadium, Jaipur     10
# 34       Punjab Cricket Association IS Bindra Stadium     10
# 35             Saurashtra Cricket Association Stadium     10
# 36                                  Brabourne Stadium     10
# 37       Himachal Pradesh Cricket Association Stadium      9
# 38                             MA Chidambaram Stadium      9
# 39                             Holkar Cricket Stadium      9
# 40                              New Wanderers Stadium      8
# 41                   Zayed Cricket Stadium, Abu Dhabi      8
# 42                 JSCA International Stadium Complex      7
# 43                                   St George's Park      7
# 44                                   Barabati Stadium      7
# 45                                           Newlands      7
# 46   Shaheed Veer Narayan Singh International Stadium      6
# 47                                      Nehru Stadium      5
# 48  Maharaja Yadavindra Singh International Cricke...      5
# 49  Punjab Cricket Association IS Bindra Stadium, ...      5
# 50                                         Green Park      4
# 51  Himachal Pradesh Cricket Association Stadium, ...      4
# 52                              De Beers Diamond Oval      3
# 53                                       Buffalo Park      3
# 54                Barsapara Cricket Stadium, Guwahati      3
# 55       Vidarbha Cricket Association Stadium, Jamtha      3
# 56                                    OUTsurance Oval      2
# 57  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...      2

# %%
data_v_rp = {'M.Chinnaswamy Stadium':'M Chinnaswamy Stadium',
             'Feroz Shah Kotla':'Arun Jaitley Stadium',
             'Sardar Patel Stadium':'Narendra Modi Stadium',
             'Punjab Cricket Association Is Bindra Stadium':'Punjab Cricket Association Stadium'}

df_matches['venue'].replace(data_v_rp,inplace = True)
print('Done')
# Out:
# Done

# %%
import warnings
warnings.filterwarnings('ignore')
team_name_rp = {'Delhi Daredevils':'Delhi Capitals',
                'Royal Challengers Bangalore':'Royal Challengers Bengaluru',
                'Kings XI Punjab':'Punjab Kings',
                'Rising Pune Supergiant':'Rising Pune Supergiants',
                'Pune Warriors':'Rising Pune Supergiants',
                'Gujarat Lions':'Gujarat Titans'}

df_matches[['team1','team2']] = df_matches[['team1','team2']].replace(team_name_rp)
print('Done')
# Out:
# Done

# %%
df_matches['venue'].value_counts().head(10)
# Out:
# venue
# M Chinnaswamy Stadium                         80
# Eden Gardens                                  77
# Arun Jaitley Stadium                          74
# Wankhede Stadium                              73
# Rajiv Gandhi International Stadium, Uppal     49
# MA Chidambaram Stadium, Chepauk               48
# Sawai Mansingh Stadium                        47
# Dubai International Cricket Stadium           46
# Wankhede Stadium, Mumbai                      45
# Punjab Cricket Association Stadium, Mohali    35
# Name: count, dtype: int64

# %%
x = df_matches['venue'].value_counts().head(10).index
y = df_matches['venue'].value_counts().head(10).values


plt.figure(figsize = (7,5))
plt.barh(x,y,color = sns.color_palette('magma',10))
plt.title('Top 10 venue by Matches Played')
plt.xticks(rotation = 90)
plt.show()

# %%
 df_matches['team1'].value_counts().reset_index()
# Out:
#                           team1  count
# 0   Royal Challengers Bengaluru    144
# 1           Chennai Super Kings    128
# 2                Delhi Capitals    126
# 3                Mumbai Indians    123
# 4                  Punjab Kings    123
# 5         Kolkata Knight Riders    121
# 6              Rajasthan Royals    101
# 7           Sunrisers Hyderabad     86
# 8               Deccan Chargers     39
# 9                Gujarat Titans     37
# 10      Rising Pune Supergiants     37
# 11         Lucknow Super Giants     23
# 12         Kochi Tuskers Kerala      7

# %%
import warnings
warnings.filterwarnings('ignore')

team_name_rp = {'Delhi Daredevils':'Delhi Capitals',
                'Royal Challengers Bangalore':'Royal Challengers Bengaluru',
                'Kings XI Punjab':'Punjab Kings',
                'Rising Pune Supergiant':'Rising Pune Supergiants',
                'Pune Warriors':'Rising Pune Supergiants'}


df_matches[['team1','team2']].replace(team_name_rp)
print('done')
# Out:
# done

# %%
df_matches[['team1','team2']].replace(team_name_rp)
# Out:
#                             team1                        team2
# 0     Royal Challengers Bengaluru        Kolkata Knight Riders
# 1                    Punjab Kings          Chennai Super Kings
# 2                  Delhi Capitals             Rajasthan Royals
# 3                  Mumbai Indians  Royal Challengers Bengaluru
# 4           Kolkata Knight Riders              Deccan Chargers
# ...                           ...                          ...
# 1090                 Punjab Kings          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092  Royal Challengers Bengaluru             Rajasthan Royals
# 1093          Sunrisers Hyderabad             Rajasthan Royals
# 1094          Sunrisers Hyderabad        Kolkata Knight Riders
#
# [1095 rows x 2 columns]

# %%
df_matches.sample(5)
# Out:
#            id   season       city       date  match_type player_of_match  \
# 913   1304084     2022     Mumbai 2022-04-25      League        S Dhawan
# 171    419162  2009/10     Mumbai 2010-04-21  Semi Final      KA Pollard
# 731   1178411     2019     Jaipur 2019-04-20      League       SPD Smith
# 641   1136566     2018     Jaipur 2018-04-11      League       SV Samson
# 1038  1422133     2024  Bangalore 2024-04-02      League        MP Yadav
#
#                                  venue                        team1  \
# 913           Wankhede Stadium, Mumbai                 Punjab Kings
# 171         Dr DY Patil Sports Academy  Royal Challengers Bengaluru
# 731             Sawai Mansingh Stadium               Mumbai Indians
# 641             Sawai Mansingh Stadium             Rajasthan Royals
# 1038  M Chinnaswamy Stadium, Bengaluru         Lucknow Super Giants
#
#                             team2                  toss_winner toss_decision  \
# 913           Chennai Super Kings          Chennai Super Kings         field
# 171                Mumbai Indians               Mumbai Indians           bat
# 731              Rajasthan Royals             Rajasthan Royals         field
# 641                Delhi Capitals               Delhi Capitals         field
# 1038  Royal Challengers Bengaluru  Royal Challengers Bengaluru         field
#
#                     winner   result  result_margin  target_runs  target_overs  \
# 913           Punjab Kings     runs          11.00       188.00         20.00
# 171         Mumbai Indians     runs          35.00       185.00         20.00
# 731       Rajasthan Royals  wickets           5.00       162.00         20.00
# 641       Rajasthan Royals     runs          10.00        71.00          6.00
# 1038  Lucknow Super Giants     runs          28.00       182.00         20.00
#
#      super_over         method        umpire2  year
# 913           N  Normal Method   Tapan Sharma  2022
# 171           N  Normal Method      RB Tiffin  2010
# 731           N  Normal Method       YC Barde  2019
# 641           N            D/L    Nitin Menon  2018
# 1038          N  Normal Method  NA Patwardhan  2024

# %%
df_matches[['toss_winner','team2']].replace(team_name_rp)
# Out:
#                       toss_winner                        team2
# 0     Royal Challengers Bengaluru        Kolkata Knight Riders
# 1             Chennai Super Kings          Chennai Super Kings
# 2                Rajasthan Royals             Rajasthan Royals
# 3                  Mumbai Indians  Royal Challengers Bengaluru
# 4                 Deccan Chargers              Deccan Chargers
# ...                           ...                          ...
# 1090                 Punjab Kings          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092             Rajasthan Royals             Rajasthan Royals
# 1093             Rajasthan Royals             Rajasthan Royals
# 1094          Sunrisers Hyderabad        Kolkata Knight Riders
#
# [1095 rows x 2 columns]

# %%
df_matches.drop(['umpire1','umpire2'],axis= 1, inplace = True)
print('Done') # deleting columnns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 df_matches.drop(['umpire1','umpire2'],axis= 1, inplace = True)
#       2 print('Done')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['umpire1'] not found in axis"

# %%
df_matches.sample(3)

# %%
team_name_rp

# %%
df_matches['toss_winner'].replace(team_name_rp,inplace = True)
df_matches['winner'].replace(team_name_rp,inplace = True)

# %%
df_matches['toss_winner'].value_counts()

# %%
df_matches['winner'].value_counts()

# %%
df_matches['match_type'].value_counts()

# %%
df_matches[df_matches['match_type'] == 'Final']['winner'].value_counts()
plt.show()

# %%
plt.title('Highest ipl session winning team')
df_matches[df_matches['match_type'] == 'Final']['winner'].value_counts().plot(kind = 'pie',autopct = '%.2f%%')
plt.show()

# %%
 final_match = df_matches[df_matches['match_type'] == 'Final']
final_match

# %%
final_match['Winning year'] = final_match['date'].dt.year
print('Done')

# %%
final_match

# %%
final_match[['Winning year','winner']].sort_values('winner')

# %%
final_match['result'].value_counts()

# %%
df_matches.groupby('venue')['result'].value_counts()

# %%
final_match.groupby('venue')['result'].value_counts().reset_index().sort_values(by ='count',ascending = False)

# %%
df_matches.groupby('venue')['result'].value_counts().reset_index().sort_values(by ='venue')

# %%
# DAY 13

# %%
# Questions to be solve?
# Each season Winner Team
# Top 10 Match Winner team
# Toss_dicision_value_counts
# Result type value_counts
# Top 10 target Runs
# Maximum Result Margin Wins
# Top 5 Result Margin Wins
# Top 10 player_of_match
# Season Player of the match

# %% [markdown]
# Each season Winner Team

# %%
final_match[['Winning year','winner']].sort_values('Winning year').plot(kind = 'bar')

# %%
season_winning_team_df = final_match[['Winning year','winner']].sort_values('Winning year')

# %% [markdown]
# Q2 Top 10 Match Winner team

# %%
df_matches['winner'].value_counts().head(10)

# %%
num_cols = df_matches.describe().columns
cat_cols = df_matches.describe(include = 'O').columns

# %%
print(num_cols)

# %%
print(cat_cols)

# %%
for i in cat_cols:
    try:
        temp_df = df_matches[i].value_counts().head(10)
        x = temp_df.index
        y = temp_df.values
    
        plt.title(f'Top 10 Analysis by {i}')
        ax = plt.barh(x,y,color = sns.color_palette('magma',10))
        plt.bar_label(ax)
        plt.xticks(rotation = 90)
        plt.show()
    except:
        pass

# %%
for i in range(len(cat_cols)):
  plt.subplot(7,2,i+1)
  plt.bar(x,y)
plt.show()

# %%
# len(cat_cols)

plt.figure(figsize = (30,45))
for j,i in enumerate(cat_cols):
  temp_df = df_matches[i].value_counts().head(10).sort_values(ascending = True)
  x = temp_df.index
  y = temp_df.values

  plt.subplot(7,2,j+1)
  plt.title(f'Top 10 Analysis by {i}')
  ax = plt.barh(x,y,color = sns.color_palette('cool',10))
  plt.bar_label(ax)
  plt.xticks(rotation = 90)
    
plt.savefig('all_category_analysis.jpeg')
plt.show()
print('done')

# %%
num_cols = list(num_cols)
num_cols.remove('id')
num_cols.remove('date')
num_cols.remove('target_overs')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[187], line 2
#       1 num_cols = list(num_cols)
# ----> 2 num_cols.remove('id')
#       3 num_cols.remove('date')
#       4 num_cols.remove('target_overs')
#
# ValueError: list.remove(x): x not in list

# %%
num_cols

# %%
# Numerical Histogram
plt.figure(figsize = (10,4))
for j,i in enumerate(num_cols):
  plt.subplot(1,2,j+1)
  plt.title(f'Distribution Analysis for {i}')
  sns.histplot(df_matches[i],color = 'PINK',kde = True) #Kernel Density Estimator (KDE)
plt.show()

# %%
# Max Target Runs which team?

df_matches[df_matches['target_runs'] == df_matches['target_runs'].max()]
# Out:
#            id season       city       date match_type player_of_match  \
# 1053  1426268   2024  Bangalore 2024-04-15     League         TM Head
#
#                                  venue                team1  \
# 1053  M Chinnaswamy Stadium, Bengaluru  Sunrisers Hyderabad
#
#                             team2                  toss_winner toss_decision  \
# 1053  Royal Challengers Bengaluru  Royal Challengers Bengaluru         field
#
#                    winner result  result_margin  target_runs  target_overs  \
# 1053  Sunrisers Hyderabad   runs          25.00       288.00         20.00
#
#      super_over         method   umpire2  year
# 1053          N  Normal Method  R Pandit  2024

# %%
# Min Target Runs which team?
temp_df = df_matches[(df_matches['winner'] != 'No winner') & (df_matches['method'] == 'Normal method')]
temp_df[temp_df['target_runs'] == temp_df['target_runs'].min()]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, match_type, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, target_runs, target_overs, super_over, method, umpire2, year]
# Index: []

# %%
df_matches.describe()
# Out:
#               id                           date  result_margin  target_runs  \
# count    1095.00                           1095        1095.00      1095.00
# mean   904828.32  2016-06-25 11:39:36.986301184          16.96       165.23
# min    335982.00            2008-04-18 00:00:00           0.00         0.00
# 25%    548331.50            2012-04-21 00:00:00           5.00       146.00
# 50%    980961.00            2016-05-03 00:00:00           8.00       166.00
# 75%   1254062.50            2021-04-13 12:00:00          19.00       187.00
# max   1426312.00            2024-05-26 00:00:00         146.00       288.00
# std    367740.24                            NaN          21.71        34.49
#
#        target_overs    year
# count       1095.00 1095.00
# mean          19.71 2016.13
# min            0.00 2008.00
# 25%           20.00 2012.00
# 50%           20.00 2016.00
# 75%           20.00 2021.00
# max           20.00 2024.00
# std            1.89    4.95

# %%
df_matches['target_runs'].value_counts().sort_index().head()
# Out:
# target_runs
# 0.00     3
# 43.00    1
# 48.00    1
# 52.00    1
# 53.00    1
# Name: count, dtype: int64

# %%
df_matches[df_matches['date'].dt.year == 2017].sort_values(by = 'winner')[['winner','result','result_margin']]
# Out:
#                           winner   result  result_margin
# 617               Delhi Capitals  wickets           7.00
# 615               Delhi Capitals  wickets           6.00
# 591               Delhi Capitals     runs          51.00
# 627               Delhi Capitals     runs           7.00
# 625               Delhi Capitals  wickets           2.00
# 585               Delhi Capitals     runs          97.00
# 589                Gujarat Lions  wickets           7.00
# 599                Gujarat Lions  wickets           4.00
# 606                Gujarat Lions  wickets           7.00
# 622                Gujarat Lions  wickets           6.00
# 587        Kolkata Knight Riders  wickets           8.00
# 590        Kolkata Knight Riders     runs          17.00
# 579        Kolkata Knight Riders  wickets          10.00
# 633        Kolkata Knight Riders  wickets           7.00
# 594        Kolkata Knight Riders  wickets           4.00
# 607        Kolkata Knight Riders  wickets           7.00
# 605        Kolkata Knight Riders  wickets           7.00
# 621        Kolkata Knight Riders  wickets           6.00
# 603        Kolkata Knight Riders     runs          82.00
# 620               Mumbai Indians     runs         146.00
# 629               Mumbai Indians     runs           9.00
# 613               Mumbai Indians  wickets           5.00
# 610               Mumbai Indians      tie           0.00
# 634               Mumbai Indians  wickets           6.00
# 635               Mumbai Indians     runs           1.00
# 600               Mumbai Indians     runs          14.00
# 598               Mumbai Indians  wickets           8.00
# 583               Mumbai Indians  wickets           4.00
# 586               Mumbai Indians  wickets           4.00
# 588               Mumbai Indians  wickets           4.00
# 592               Mumbai Indians  wickets           6.00
# 602                 Punjab Kings     runs          26.00
# 580                 Punjab Kings  wickets           6.00
# 626                 Punjab Kings     runs           7.00
# 624                 Punjab Kings     runs          14.00
# 584                 Punjab Kings  wickets           8.00
# 618                 Punjab Kings     runs          19.00
# 611                 Punjab Kings  wickets          10.00
# 614      Rising Pune Supergiants  wickets           5.00
# 578      Rising Pune Supergiants  wickets           7.00
# 616      Rising Pune Supergiants  wickets           4.00
# 601      Rising Pune Supergiants  wickets           6.00
# 619      Rising Pune Supergiants     runs          12.00
# 632      Rising Pune Supergiants     runs          20.00
# 609      Rising Pune Supergiants     runs          61.00
# 630      Rising Pune Supergiants  wickets           9.00
# 593      Rising Pune Supergiants     runs          27.00
# 604      Rising Pune Supergiants     runs           3.00
# 631  Royal Challengers Bengaluru     runs          10.00
# 581  Royal Challengers Bengaluru     runs          15.00
# 596  Royal Challengers Bengaluru     runs          21.00
# 628          Sunrisers Hyderabad  wickets           8.00
# 582          Sunrisers Hyderabad  wickets           9.00
# 623          Sunrisers Hyderabad  wickets           7.00
# 608          Sunrisers Hyderabad     runs          26.00
# 595          Sunrisers Hyderabad     runs           5.00
# 612          Sunrisers Hyderabad     runs          48.00
# 597          Sunrisers Hyderabad     runs          15.00
# 577          Sunrisers Hyderabad     runs          35.00

# %%
df_matches.iloc[603,:]
# Out:
# id                                     1082617
# season                                    2017
# city                                   Kolkata
# date                       2017-04-23 00:00:00
# match_type                              League
# player_of_match                NM Coulter-Nile
# venue                             Eden Gardens
# team1                    Kolkata Knight Riders
# team2              Royal Challengers Bengaluru
# toss_winner        Royal Challengers Bengaluru
# toss_decision                            field
# winner                   Kolkata Knight Riders
# result                                    runs
# result_margin                            82.00
# target_runs                             132.00
# target_overs                             20.00
# super_over                                   N
# method                           Normal Method
# umpire2                              CK Nandan
# year                                      2017
# Name: 603, dtype: object

# %%
# Stadium wise Team highest score

df_matches.groupby(['venue','team1'])['target_runs'].agg(['max','min','mean'])
# Out:
#                                                                 max    min  \
# venue                            team1
# Arun Jaitley Stadium             Chennai Super Kings         193.00 193.00
#                                  Delhi Capitals              232.00   0.00
#                                  Gujarat Titans              163.00 163.00
#                                  Kolkata Knight Riders       186.00 186.00
#                                  Mumbai Indians              169.00 169.00
# ...                                                             ...    ...
# Zayed Cricket Stadium, Abu Dhabi Kolkata Knight Riders       172.00 172.00
#                                  Mumbai Indians              236.00 156.00
#                                  Punjab Kings                136.00 136.00
#                                  Royal Challengers Bengaluru  93.00  93.00
#                                  Sunrisers Hyderabad         142.00 142.00
#
#                                                                mean
# venue                            team1
# Arun Jaitley Stadium             Chennai Super Kings         193.00
#                                  Delhi Capitals              160.97
#                                  Gujarat Titans              163.00
#                                  Kolkata Knight Riders       186.00
#                                  Mumbai Indians              169.00
# ...                                                             ...
# Zayed Cricket Stadium, Abu Dhabi Kolkata Knight Riders       172.00
#                                  Mumbai Indians              196.00
#                                  Punjab Kings                136.00
#                                  Royal Challengers Bengaluru  93.00
#                                  Sunrisers Hyderabad         142.00
#
# [271 rows x 3 columns]

# %%
# Pivot table

df_matches['year'] = df_matches['date'].dt.year
df_matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire2', 'year'],
#       dtype='object')

# %%
all_team_year_df = df_matches.pivot_table(index = 'year',columns ='team1',values = 'target_runs',aggfunc= 'min')
all_team_year_df = all_team_year_df.round(0)

# %%
plt.figure(figsize = (15,7))
# pd.options.display.float_format = '{:.2f}'.format
sns.heatmap(all_team_year_df,fmt="",annot = True,cmap='magma')
plt.show()

# %% [markdown]
# LOC VS ILOC
# LOC IS LOCATION/VALUE BASED
# ILOC IS INDEX BASED

# %%
df_matches.loc[50:55,['team1','team2','result']]
# Out:
#                           team1                team2   result
# 50        Kolkata Knight Riders         Punjab Kings  wickets
# 51             Rajasthan Royals       Mumbai Indians  wickets
# 52              Deccan Chargers  Chennai Super Kings  wickets
# 53  Royal Challengers Bengaluru       Mumbai Indians  wickets
# 54                 Punjab Kings     Rajasthan Royals     runs
# 55               Delhi Capitals     Rajasthan Royals     runs

# %%
df_matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire2', 'year'],
#       dtype='object')

# %%
df_matches.iloc[50:55,[7,8,12]]
# Out:
#                           team1                team2   result
# 50        Kolkata Knight Riders         Punjab Kings  wickets
# 51             Rajasthan Royals       Mumbai Indians  wickets
# 52              Deccan Chargers  Chennai Super Kings  wickets
# 53  Royal Challengers Bengaluru       Mumbai Indians  wickets
# 54                 Punjab Kings     Rajasthan Royals     runs

# %%
df_matches=df_matches.drop(['umpire2'],axis = 1)

# %%
df_matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'year'],
#       dtype='object')

# %%
rows = df_matches[df_matches['year']>=2016].index 
# shows index values where year is 2016

df_matches.iloc[rows ,-3:] # shows the last three colmuns
# Out:
#      super_over         method  year
# 517           N  Normal Method  2016
# 518           N  Normal Method  2016
# 519           N  Normal Method  2016
# 520           N  Normal Method  2016
# 521           N  Normal Method  2016
# ...         ...            ...   ...
# 1090          N  Normal Method  2024
# 1091          N  Normal Method  2024
# 1092          N  Normal Method  2024
# 1093          N  Normal Method  2024
# 1094          N  Normal Method  2024
#
# [578 rows x 3 columns]

# %%
df_deliveries.sample(5)
# Out:
#         match_id  inning           batting_team         bowling_team  over  \
# 223379   1304110       1         Delhi Capitals         Punjab Kings    17
# 201160   1254089       1    Chennai Super Kings     Rajasthan Royals    10
# 195454   1254065       1           Punjab Kings  Chennai Super Kings    17
# 109016    829705       2  Kolkata Knight Riders       Mumbai Indians     7
# 203460   1254099       1           Punjab Kings       Mumbai Indians     6
#
#         ball          batter           bowler      non_striker  batsman_runs  \
# 223379     2        MR Marsh   Arshdeep Singh         AR Patel             1
# 201160     5      RD Gaikwad       M Markande           MM Ali             1
# 195454     3  Mohammed Shami        SN Thakur  M Shahrukh Khan             1
# 109016     2       G Gambhir  Harbhajan Singh        MK Pandey             2
# 203460     4      AK Markram       KA Pollard         KL Rahul             1
#
#         extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 223379           0           1         NaN          0              NaN
# 201160           0           1         NaN          0              NaN
# 195454           0           1         NaN          0              NaN
# 109016           0           2         NaN          0              NaN
# 203460           0           1         NaN          0              NaN
#
#        dismissal_kind fielder
# 223379            NaN     NaN
# 201160            NaN     NaN
# 195454            NaN     NaN
# 109016            NaN     NaN
# 203460            NaN     NaN

# %%
df_deliveries.iloc[129729,:]
# Out:
# match_id                      980961
# inning                             2
# batting_team        Delhi Daredevils
# bowling_team           Gujarat Lions
# over                               1
# ball                               3
# batter                       RR Pant
# bowler                   DS Kulkarni
# non_striker                Q de Kock
# batsman_runs                       4
# extra_runs                         0
# total_runs                         4
# extras_type                      NaN
# is_wicket                          0
# player_dismissed                 NaN
# dismissal_kind                   NaN
# fielder                          NaN
# Name: 129729, dtype: object

# %%
df_deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
#  16  fielder           9354 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 33.8+ MB

# %%
df_deliveries.isna().sum().sort_values(ascending= False)
# Out:
# fielder             251566
# dismissal_kind      247970
# player_dismissed    247970
# extras_type         246795
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# non_striker              0
# bowler                   0
# batter                   0
# ball                     0
# total_runs               0
# extra_runs               0
# batsman_runs             0
# is_wicket                0
# dtype: int64

# %%
df_deliveries.loc[:,['fielder','dismissal_kind','player_dismissed','extras_type']]
normal_cols = ['fielder','dismissal_kind','player_dismissed','extras_type']

# %%
for i in normal_cols:
  print(f'Analysis for {i}\n\n')
  display(df_deliveries[i].value_counts().head(10))
# Out:
# Analysis for fielder
# fielder
# MS Dhoni          220
# KD Karthik        199
# AB de Villiers    141
# RV Uthappa        133
# V Kohli           131
# WP Saha           131
# SK Raina          119
# RA Jadeja         116
# SV Samson         115
# RG Sharma         111
# Name: count, dtype: int64
# Analysis for dismissal_kind
# dismissal_kind
# caught                   8063
# bowled                   2212
# run out                  1114
# lbw                       800
# caught and bowled         367
# stumped                   358
# retired hurt               15
# hit wicket                 15
# obstructing the field       3
# retired out                 3
# Name: count, dtype: int64
# Analysis for player_dismissed
# player_dismissed
# RG Sharma     223
# V Kohli       207
# S Dhawan      193
# KD Karthik    184
# RV Uthappa    180
# SK Raina      171
# DA Warner     164
# AT Rayudu     155
# AM Rahane     154
# SV Samson     144
# Name: count, dtype: int64
# Analysis for extras_type
# extras_type
# wides      8380
# legbyes    4001
# noballs    1069
# byes        673
# penalty       2
# Name: count, dtype: int64

# %%
sns.heatmap(df_deliveries.isna())
# Out:
# <Axes: >

# %%
df_deliveries.fillna('Unknown', inplace = True)
print('Done')
# Out:
# Done

# %%
plt.title('Checking Null values Distribution!!')
sns.heatmap(df_deliveries.isna())
plt.show()

# %%
df_deliveries.sample()
# Out:
#        match_id  inning                 batting_team           bowling_team  \
# 17361    392199       2  Royal Challengers Bangalore  Kolkata Knight Riders
#
#        over  ball      batter    bowler       non_striker  batsman_runs  \
# 17361    17     3  MV Boucher  BJ Hodge  RE van der Merwe             6
#
#        extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 17361           0           6     Unknown          0          Unknown
#
#       dismissal_kind  fielder
# 17361        Unknown  Unknown

# %%
batsman = 'DA Miller'


def get_player_perfromance_stats(batsman):

  player_df =df_deliveries[df_deliveries['batter'] == batsman]

  x = player_df['batsman_runs'].value_counts().sort_index().index
  y = player_df['batsman_runs'].value_counts().sort_index().values
  plt.figure(figsize = (4,2))
  plt.title(f'Analysis for {batsman}')
  ax = plt.bar(x,y,color = sns.color_palette('magma',7))
  plt.bar_label(ax)
  plt.show()

  total_runs = player_df['batsman_runs'].sum()

  print(f'{batsman} Total Runs in IPL History: {total_runs}')


  print(f'Batsman {batsman} Top 10 Performance Against Bowlers')
  perfomance_df = player_df.groupby('bowler')['batsman_runs'].agg(['sum','mean']).reset_index().sort_values(by = 'sum',ascending=False).head(10)


  display(perfomance_df)

# %%
player_df.groupby('bowler')['batsman_runs'].agg(['sum','mean'])
# Out:
#                 sum  mean
# bowler
# A Ashish Reddy   12  2.00
# A Mishra         68  1.31
# A Nehra          19  1.19
# A Nortje         31  2.21
# A Zampa           6  1.20
# ...             ...   ...
# YS Chahal        77  1.71
# Yash Dayal       17  1.21
# Yash Thakur      11  1.83
# Yuvraj Singh     11  2.20
# Z Khan            2  0.33
#
# [178 rows x 2 columns]

# %%
all_batsman = df_deliveries['batter'].unique()
print('done')
# Out:
# done

# %%
import random
for i in random.choices(all_batsman,k = 5):
  get_player_perfromance_stats(i)
# Out:
# DR Sams Total Runs in IPL History: 44
# Batsman DR Sams Top 10 Performance Against Bowlers
#                bowler  sum  mean
# 18  Washington Sundar   13  2.17
# 15          SN Thakur    7  2.33
# 8              KR Sen    6  6.00
# 10       M Theekshana    5  2.50
# 14       Ravi Bishnoi    3  1.00
# 1          Avesh Khan    3  1.50
# 13       PVD Chameera    2  0.40
# 17        Umran Malik    1  0.25
# 12         PJ Cummins    1  0.50
# 16    Simarjeet Singh    1  0.50
# NM Coulter-Nile Total Runs in IPL History: 82
# Batsman NM Coulter-Nile Top 10 Performance Against Bowlers
#             bowler  sum  mean
# 17  Mohammed Shami   12  2.00
# 25  Sandeep Sharma    9  1.80
# 1   Arshdeep Singh    9  3.00
# 8      DS Kulkarni    6  1.50
# 16      MG Johnson    6  1.50
# 13      JD Unadkat    6  3.00
# 10         GB Hogg    4  1.33
# 6          D Wiese    4  1.33
# 11       IC Pandey    4  2.00
# 5        CJ Jordan    3  1.00
# MM Ali Total Runs in IPL History: 1162
# Batsman MM Ali Top 10 Performance Against Bowlers
#                bowler  sum  mean
# 71        Rashid Khan   58  1.35
# 66           R Ashwin   55  1.17
# 43      Kuldeep Yadav   48  2.29
# 86           TA Boult   43  2.15
# 95          YS Chahal   40  1.38
# 49  M Prasidh Krishna   37  1.48
# 12         Avesh Khan   37  1.61
# 55     Mohammed Shami   35  1.25
# 72       Ravi Bishnoi   33  1.57
# 69          RD Chahar   30  1.15
# Sanvir Singh Total Runs in IPL History: 25
# Batsman Sanvir Singh Top 10 Performance Against Bowlers
#            bowler  sum  mean
# 6      N Thushara    6  1.00
# 5  Mohammed Shami    6  1.50
# 0   Atharva Taide    4  4.00
# 1       CJ Jordan    4  1.33
# 2   Harpreet Brar    2  0.67
# 3       JJ Bumrah    2  1.00
# 7     Rashid Khan    1  1.00
# 4       MM Sharma    0  0.00
# 8       SP Narine    0  0.00
# AU Rashid Total Runs in IPL History: 22
# Batsman AU Rashid Top 10 Performance Against Bowlers
#       bowler  sum  mean
# 1   NA Saini    7  1.40
# 2   R Ashwin    6  1.50
# 3  YS Chahal    5  1.00
# 0   A Mishra    4  1.33

# %%
import random
for i in random.choices(all_batsman,k = 5):
  get_player_perfromance_stats(i)
# Out:
# Dhruv Jurel Total Runs in IPL History: 347
# Batsman Dhruv Jurel Top 10 Performance Against Bowlers
#              bowler  sum  mean
# 28      Mohsin Khan   25  3.12
# 27   Mohammed Siraj   21  2.10
# 45     TU Deshpande   21  2.10
# 22      M Pathirana   20  2.50
# 48      Yash Thakur   19  1.46
# 33       PJ Cummins   17  1.55
# 5   Abhishek Sharma   17  1.42
# 8    Arshdeep Singh   15  2.14
# 40        SN Thakur   12  1.50
# 29     Mukesh Kumar   12  3.00
# KM Asif Total Runs in IPL History: 0
# Batsman KM Asif Top 10 Performance Against Bowlers
#       bowler  sum  mean
# 0  KV Sharma    0  0.00
# P Awana Total Runs in IPL History: 5
# Batsman P Awana Top 10 Performance Against Bowlers
#         bowler  sum  mean
# 7     VR Aaron    3  1.00
# 0    CH Morris    1  1.00
# 4     M Morkel    1  0.50
# 1    DJG Sammy    0  0.00
# 3  JP Faulkner    0  0.00
# 2    DP Nannes    0  0.00
# 5   MG Johnson    0  0.00
# 6   SL Malinga    0  0.00
# PC Valthaty Total Runs in IPL History: 505
# Batsman PC Valthaty Top 10 Performance Against Bowlers
#         bowler  sum  mean
# 20   JA Morkel   34  2.83
# 44  SK Trivedi   24  3.00
# 31     MS Gony   23  2.56
# 37    S Randiv   23  1.77
# 50  TG Southee   22  1.57
# 57      Z Khan   21  1.24
# 24    JR Hopes   21  1.62
# 17   IK Pathan   20  1.33
# 32    R Ashwin   19  1.46
# 0     A Mishra   18  1.12
# M Vohra Total Runs in IPL History: 1083
# Batsman M Vohra Top 10 Performance Against Bowlers
#              bowler  sum  mean
# 52         M Morkel   43  1.26
# 78      Rashid Khan   39  2.29
# 13          BB Sran   36  2.12
# 40        JP Duminy   35  1.84
# 90        SR Watson   34  1.48
# 4          AB Dinda   31  2.21
# 99         UT Yadav   30  1.00
# 89        SP Narine   29  0.97
# 94  Shakib Al Hasan   28  1.27
# 62   Mohammed Shami   26  1.86
